# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
import requests
from dotenv import load_dotenv, find_dotenv
from newsapi import NewsApiClient
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Lendl\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
# YOUR CODE HERE!
load_dotenv(find_dotenv())
news_api_key = os.getenv("NEWS_API")

# %%
# Create a newsapi client
# YOUR CODE HERE!
newsapi = NewsApiClient(api_key=news_api_key)

# %%
# Fetch the Bitcoin news articles
# YOUR CODE HERE!
btc_news = newsapi.get_everything(
    q="bitcoin AND Bitcoin AND 2021",
    language="en"
)

btc_news["totalResults"]
# Out:
# 3131

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
eth_news = newsapi.get_everything(
    q="ethereum AND Ethereum AND 2021",
    language="en"
)

eth_news["totalResults"]
# Out:
# 1125

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!
bitcoin_sentiments = []

for article in btc_news["articles"]:
    text = article["content"]
    title = article["title"]
    date = article["publishedAt"][:10]
    sentiment = analyzer.polarity_scores(text)
    compound = sentiment["compound"]
    pos = sentiment["pos"]
    neu = sentiment["neu"]
    neg = sentiment["neg"]
        
    bitcoin_sentiments.append({
        "Text": text,
        "Date": date,
        "Compound": compound,
        "Positive": pos,
        "Negative": neg,
        "Neutral": neu,
        "Title Bitcoin": title,
    })
        
btc_sentiment_df = pd.DataFrame(bitcoin_sentiments)
btc_sentiment_df.drop(columns=['Date', 'Title Bitcoin'], inplace=True)
cols = ["Compound","Negative","Neutral","Positive","Text"]
btc_sentiment_df = btc_sentiment_df[cols]
btc_sentiment_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.7264     0.000    0.836     0.164
# 1   -0.6124     0.143    0.857     0.000
# 2    0.6240     0.000    0.873     0.127
# 3    0.0000     0.000    1.000     0.000
# 4   -0.7096     0.217    0.724     0.059
#
#                                                 Text
# 0  While retail investors grew more comfortable b...
# 1  image copyrightGetty Images\r\nThe gang behind...
# 2  To get a roundup of TechCrunchs biggest and mo...
# 3  Prices go up, prices go down -- but Bitcoin is...
# 4  Critics argue that the energy-intensive bitcoi...

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!
ethereum_sentiments = []

for article in eth_news["articles"]:
    text = article["content"]
    title = article["title"]
    date = article["publishedAt"][:10]
    sentiment = analyzer.polarity_scores(text)
    compound = sentiment["compound"]
    pos = sentiment["pos"]
    neu = sentiment["neu"]
    neg = sentiment["neg"]
        
    ethereum_sentiments.append({
        "Text": text,
        "Compound": compound,
        "Positive": pos,
        "Negative": neg,
        "Neutral": neu,
    })
        
eth_sentiment_df = pd.DataFrame(ethereum_sentiments)
cols = ["Compound","Negative","Neutral","Positive","Text"]
eth_sentiment_df = eth_sentiment_df[cols]
eth_sentiment_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0   -0.2411     0.061    0.939     0.000
# 1    0.7264     0.000    0.836     0.164
# 2    0.0000     0.000    1.000     0.000
# 3    0.7717     0.000    0.806     0.194
# 4    0.6249     0.000    0.850     0.150
#
#                                                 Text
# 0  Blockchain infrastructure startups are heating...
# 1  While retail investors grew more comfortable b...
# 2  Representations of cryptocurrencies Bitcoin an...
# 3  Ether holders have "staked" more than $13 bill...
# 4  Ether is the cryptocurrency of the ethereum ne...

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!
btc_sentiment_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.026125   0.037950   0.932000   0.030050
# std     0.391630   0.076906   0.093386   0.049016
# min    -0.812600   0.000000   0.714000   0.000000
# 25%    -0.060275   0.000000   0.869500   0.000000
# 50%     0.000000   0.000000   1.000000   0.000000
# 75%     0.000000   0.015250   1.000000   0.053750
# max     0.726400   0.249000   1.000000   0.164000

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
eth_sentiment_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.091450   0.021250   0.939750   0.039000
# std     0.346668   0.046055   0.085266   0.070316
# min    -0.726900   0.000000   0.782000   0.000000
# 25%     0.000000   0.000000   0.846500   0.000000
# 50%     0.000000   0.000000   1.000000   0.000000
# 75%     0.062500   0.010500   1.000000   0.030750
# max     0.771700   0.186000   1.000000   0.194000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum has the highest mean positive score of 0.039
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum has the highest compound score of 0.7717
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum has the highest positive score of 0.194

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
# YOUR CODE HERE!

# Expand the default stopwords list if necessary
# YOUR CODE HERE!
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lendl\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lendl\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lendl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    sw_addons = {'said', 'sent', 'found', 'including', 'today', 'announced', 'week', 'basically', 'also', 'chars', 'illustration'}
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    output = [lemmatizer.lemmatize(word.lower()) for word in words if word.lower() not in set(stopwords.words('english'))]
    output2 = [word.lower() for word in words if word.lower() not in sw.union(sw_addons)]
    return output2

# %%
# Create a new tokens column for Bitcoin
# YOUR CODE HERE!
btc_sentiment_df["Tokens"] = btc_sentiment_df["Text"].apply(tokenizer)
btc_sentiment_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.7264     0.000    0.836     0.164
# 1   -0.6124     0.143    0.857     0.000
# 2    0.6240     0.000    0.873     0.127
# 3    0.0000     0.000    1.000     0.000
# 4   -0.7096     0.217    0.724     0.059
#
#                                                 Text  \
# 0  While retail investors grew more comfortable b...
# 1  image copyrightGetty Images\r\nThe gang behind...
# 2  To get a roundup of TechCrunchs biggest and mo...
# 3  Prices go up, prices go down -- but Bitcoin is...
# 4  Critics argue that the energy-intensive bitcoi...
#
#                                               Tokens
# 0  [retail, investors, grew, comfortable, buying,...
# 1  [image, copyrightgetty, imagesthe, gang, behin...
# 2  [get, roundup, techcrunchs, biggest, important...
# 3  [prices, go, prices, go, bitcoin, stay, crypto...
# 4  [critics, argue, energyintensive, bitcoin, min...

# %%
# Create a new tokens column for Ethereum
# YOUR CODE HERE!
eth_sentiment_df["Tokens"] = eth_sentiment_df["Text"].apply(tokenizer)
eth_sentiment_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0   -0.2411     0.061    0.939     0.000
# 1    0.7264     0.000    0.836     0.164
# 2    0.0000     0.000    1.000     0.000
# 3    0.7717     0.000    0.806     0.194
# 4    0.6249     0.000    0.850     0.150
#
#                                                 Text  \
# 0  Blockchain infrastructure startups are heating...
# 1  While retail investors grew more comfortable b...
# 2  Representations of cryptocurrencies Bitcoin an...
# 3  Ether holders have "staked" more than $13 bill...
# 4  Ether is the cryptocurrency of the ethereum ne...
#
#                                               Tokens
# 0  [blockchain, infrastructure, startups, heating...
# 1  [retail, investors, grew, comfortable, buying,...
# 2  [representations, cryptocurrencies, bitcoin, e...
# 3  [ether, holders, staked, billion, worth, crypt...
# 4  [ether, cryptocurrency, ethereum, networkphoto...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
def get_tokens(df):
    tokens = []
    for token in df['Tokens']:
        tokens.extend(token)
    return tokens

btc_tokens = get_tokens(btc_sentiment_df)
eth_tokens = get_tokens(eth_sentiment_df)

def bigram_counter(tokens, N): 
    words_count = dict(Counter(ngrams(tokens, n=N)))
    return words_count

# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
bigram_btc = bigram_counter(btc_tokens, 2)

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!
bigram_eth = bigram_counter(eth_tokens, 2)

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!
btc_token_count = token_count(bigram_btc, 10)
btc_token_count
# Out:
# [(('taken', 'june'), 7),
#  (('picture', 'taken'), 5),
#  (('july', 'reuters'), 4),
#  (('representations', 'bitcoin'), 4),
#  (('seen', 'picture'), 4),
#  (('june', 'reutersedgar'), 4),
#  (('bitcoin', 'ethereum'), 3),
#  (('bitcoin', 'seen'), 3),
#  (('bitcoin', 'cryptocurrency'), 3),
#  (('cryptocurrency', 'seen'), 3)]

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!
eth_token_count = token_count(bigram_eth, 10)
eth_token_count
# Out:
# [(('taken', 'june'), 8),
#  (('representations', 'cryptocurrencies'), 6),
#  (('cryptocurrency', 'ethereum'), 6),
#  (('bitcoin', 'ethereum'), 5),
#  (('placed', 'pc'), 5),
#  (('pc', 'motherboard'), 5),
#  (('motherboard', 'taken'), 5),
#  (('june', 'reutersdado'), 5),
#  (('cryptocurrencies', 'bitcoin'), 4),
#  (('ethereum', 'dogecoin'), 3)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!
cloud = WordCloud(collocations=False).generate(' '.join(btc_tokens))
plt.imshow(cloud)
plt.title(label='Bitcoin Word Cloud', fontdict={'fontsize': 50, 'fontweight':'bold'})
# Out:
# Text(0.5, 1.0, 'Bitcoin Word Cloud')

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!
cloud = WordCloud(collocations=False).generate(' '.join(eth_tokens))
plt.imshow(cloud)
plt.title(label='Ethereum Word Cloud', fontdict={'fontsize': 50, 'fontweight':'bold'})
# Out:
# Text(0.5, 1.0, 'Ethereum Word Cloud')

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!
btc_texts = ' '.join(btc_sentiment_df['Text'])
print(btc_texts)
# Out:
# While retail investors grew more comfortable buying cryptocurrencies like Bitcoin and Ethereum in 2021, the decentralized application world still has a lot of work to do when it comes to onboarding a… [+2288 chars] image copyrightGetty Images
# The gang behind a "colossal" ransomware attack has demanded $70m (£50.5m) paid in Bitcoin in return for a "universal decryptor" that it says will unlock the files of all … [+4140 chars] To get a roundup of TechCrunchs biggest and most important stories delivered to your inbox every day at 3 p.m. PDT, subscribe here.
# Hello and welcome to Daily Crunch for July 23, 2021. Its been an i… [+5456 chars] Prices go up, prices go down -- but Bitcoin is here to stay. And as cryptocurrency continues its march toward the mainstream, and becomes more entwined with the global economy, sooner or later you're… [+10626 chars] Critics argue that the energy-intensive bitcoin mining process is bad for the planet.
# Lars Hagberg/Getty Images
# Shares of cryptocurrency mining companies soared in early Monday morning trading as b… [+1207 chars] Representations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, Litecoin are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationWASHINGTON, Ju… [+3970 chars] Representations of virtual currency bitcoin are seen in front of Tesla logo in this illustration taken, February 9, 2021. REUTERS/Dado RuvicJuly 21 (Reuters) - Electric-car maker Tesla Inc (TSLA.O) w… [+711 chars] Representations of cryptocurrencies Bitcoin and Ethereum are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationAug 3 (Reuters) - The Ethereum platform… [+2412 chars] Ransomware attacks, fueled by COVID-19 pandemic turbulence, have become a major money earner for cybercriminals, with the number of attacks rising in 2020.
# These file-encrypting attacks have continu… [+4082 chars] REUTERS/Dado Ruvic/Illustration
# Welcome to 10 Things Before the Opening Bell. If this was forwarded to you, sign up here.
# Markets Insider is selling its first NFTs. Get the details here.
# Let's get… [+2549 chars] By Reuters Staff
# Amazon app is seen on a smartphone in this illustration taken, July 13, 2021. REUTERS/Dado Ruvic/Illustration
# (Reuters) - Amazon.com Inc on Monday denied a media report saying the … [+1079 chars] A representation of virtual currency Bitcoin is seen in front of a stock graph in this illustration taken March 15, 2021. REUTERS/Dado Ruvic/Illustration/File PhotoSAN SALVADOR, July 8 (Reuters) - In… [+1504 chars] Representations of the Bitcoin cryptocurrency are seen in this illustration picture taken June 7, 2021. REUTERS/Edgar Su/Illustration/File PhotoJuly 9 (Reuters) - Square Inc (SQ.N) will make a hardwa… [+1675 chars] Blockchain infrastructure startups are heating up as industry fervor brings more developers and users to a space that still feels extremely young despite a heavy institutional embrace of the crypto s… [+2468 chars] Representations of the Bitcoin cryptocurrency are seen in this illustration picture taken June 7, 2021. REUTERS/Edgar Su/IllustrationNEW YORK, July 19 (Reuters) - Bitcoin investment products and fund… [+2098 chars] A representation of the virtual cryptocurrency Bitcoin is seen in this picture illustration taken June 14, 2021. REUTERS/Edgar Su/Illustration/FilesNEW YORK, Aug 2 (Reuters) - Cryptocurrency investme… [+2265 chars] A Chinese flag is seen among representations of Bitcoin and other cryptocurrencies in this illustration picture taken June 2, 2021. REUTERS/Florence Lo/IllustrationLONDON, July 15 (Reuters) - China's… [+1974 chars] This story originally appeared on be[IN]cryptoMaryland-based ProFunds is launching a publicly available mutual fund connected to the value of bitcoin (BTC).
# The Bitcoin Strategy ProFund invests in b… [+1875 chars] Representations of the Bitcoin cryptocurrency are seen in this illustration picture taken June 7, 2021. REUTERS/Edgar Su/Illustration/File PhotoLONDON, July 12 (Reuters) - Trading volumes at major cr… [+1271 chars] FILE PHOTO: The Bank of England can be seen as people cycle through the City of London financial district, in London, Britain, June 11, 2021. REUTERS/Henry Nicholls/File Photo
# LONDON (Reuters) - Hig… [+1739 chars]

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
doc= nlp(btc_texts)
# Add a title to the document
# YOUR CODE HERE!
doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">While retail investors grew more comfortable buying cryptocurrencies like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin and Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the decentralized application world still has a lot of work to do when it comes to onboarding a… [+2288 chars] image
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     copyrightGetty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>The gang behind a &quot;colossal&quot; ransomware attack has demanded
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $70m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     £50.5m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ) paid in Bitcoin in return for a &quot;universal decryptor&quot; that it says will unlock the files of all … [+4140 chars] To get a roundup of TechCrunchs biggest and most important stories delivered to your inbox
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     every day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3 p.m. PDT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# </br>Hello and welcome to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Daily Crunch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 23, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lars Hagberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# /
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Shares of cryptocurrency mining companies soared in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     early Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  trading as b… [+1207 chars] Representations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, Litecoin are placed on PC motherboard in this illustration taken,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 29, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     REUTERS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dado Ruvic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# /IllustrationWASHINGTON,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ju
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# … [+3970 chars] Representations of virtual currency bitcoin are seen in front of Tesla logo in this illustration taken,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February 9, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     REUTERS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dado
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  RuvicJuly 21 (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Electric-car maker
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (TSLA.O) w… [+711 chars] Representations of cryptocurrencies Bitcoin and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethe

# %%
# List all Entities
# YOUR CODE HERE!
for ent in doc.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# Bitcoin and Ethereum ORG
# 2021 DATE
# copyrightGetty Images PERSON
# $70m MONEY
# £50.5m MONEY
# every day DATE
# 3 p.m. PDT TIME
# Daily Crunch ORG
# July 23, 2021 DATE
# Lars Hagberg PERSON
# Getty Images ORG
# early Monday DATE
# morning TIME
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic PERSON
# Ju PERSON
# February 9, 2021 DATE
# REUTERS ORG
# Dado GPE
# Reuters ORG
# Tesla Inc ORG
# Ethereum PERSON
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/IllustrationAug 3 PERSON
# Reuters ORG
# Ethereum PERSON
# 2020 DATE
# REUTERS ORG
# Dado Ruvic/Illustration
# Welcome PERSON
# 10 CARDINAL
# the Opening Bell ORG
# first ORDINAL
# Reuters ORG
# July 13, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration ORG
# Reuters ORG
# Monday DATE
# March 15, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration/File PhotoSAN SALVADOR ORG
# July 8 DATE
# Reuters ORG
# June 7, 2021 DATE
# REUTERS ORG
# Edgar Su/Illustration/File PERSON
# 9 DATE
# Reuters ORG
# June 7, 2021 DATE
# REUTERS ORG
# Edgar Su/IllustrationNEW PERSON
# July 19 DATE
# Reuters ORG
# June 14, 2021 DATE
# REUTERS ORG
# Edgar Su/Illustration/FilesNEW YORK PERSON
# Aug 2 DATE
# Reuters ORG
# Chinese NORP
# June 2, 2021 DATE
# REUTERS ORG
# Florence Lo PERSON
# July 15 DATE
# Reuters ORG
# China GPE
# be[IN]cryptoMaryland ORG
# ProFunds ORG
# June 7, 2021 DATE
# REUTERS ORG
# Edgar Su/Illustration/File PERSON
# July 12 DATE
# Reuters ORG
# FILE ORG
# The Bank of England ORG
# the City of London GPE
# London GPE
# Britain GPE
# June 11, 2021 DATE
# REUTERS ORG
# Henry Nicholls/ PERSON
# LONDON GPE
# Reuters ORG

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!
eth_texts = ' '.join(eth_sentiment_df['Text'])
print(eth_texts)
# Out:
# Blockchain infrastructure startups are heating up as industry fervor brings more developers and users to a space that still feels extremely young despite a heavy institutional embrace of the crypto s… [+2468 chars] While retail investors grew more comfortable buying cryptocurrencies like Bitcoin and Ethereum in 2021, the decentralized application world still has a lot of work to do when it comes to onboarding a… [+2288 chars] Representations of cryptocurrencies Bitcoin and Ethereum are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationAug 3 (Reuters) - The Ethereum platform… [+2412 chars] Ether holders have "staked" more than $13 billion worth of the cryptocurrency on the ethereum 2.0 network, as excitement builds around the overhaul of the system and the potential growth of the staki… [+1851 chars] Ether is the cryptocurrency of the ethereum network.
# Photothek/Getty Images
# Ether holders have "staked" more than $13 billion worth of the cryptocurrency on the ethereum 2.0 network, as excitement … [+1935 chars] Representations of cryptocurrency Ethereum are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationNEW YORK, July 30 (Reuters) - Ethereum, the second-la… [+3949 chars] All the sessions from Transform 2021 are available on-demand now. Watch now.
# Livepeer has raised $20 million for its decentralized video transcoding network built on the Ethereum blockchain. Its ano… [+6544 chars] After a successful testnet deployement, the London upgrade is now ready to be activated on the Ethereum mainnet. It will go live on block 12 965 000, which is expected between August 3-5, 2021.
# Clie… [+5964 chars] This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.
# The Securities and Exchange Commission (CVM), the body that regulates securities in … [+1015 chars] Representations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, Litecoin are placed on PC motherboard in this illustration taken June 29, 2021. REUTERS/Dado Ruvic/Illustration/File PhotoNEW … [+2012 chars] NEW YORK (Reuters) - Cryptocurrency investment products and funds posted outflows to start the second half of the year, as cautious sentiment persisted in the midst of a summer lull, according to dat… [+1892 chars] Representations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, Litecoin are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/Illustration/File Photo
# J… [+806 chars] Representations of virtual currency bitcoin are seen in front of Tesla logo in this illustration taken, February 9, 2021. REUTERS/Dado RuvicJuly 21 (Reuters) - Electric-car maker Tesla Inc (TSLA.O) w… [+711 chars] By Reuters Staff
# A representation of the virtual cryptocurrency Ethereum is seen among representations of other cryptocurrencies in this picture illustration taken June 14, 2021. REUTERS/Edgar Su/Il… [+852 chars] A representation of the virtual cryptocurrency Bitcoin is seen in this picture illustration taken June 14, 2021. REUTERS/Edgar Su/Illustration/FilesNEW YORK, Aug 2 (Reuters) - Cryptocurrency investme… [+2265 chars] Chung Sung-Jun/Getty Images
# OpenSea, a marketplace for digital collectibles, hit a valuation of $1.5 billion in its latest round of fundraising, according to reports, highlighting bullishness in the… [+1909 chars] All the sessions from Transform 2021 are available on-demand now. Watch now.
# Polygon, a maker of a crypto-based platform for nonfungible tokens (NFTs), has set up a $100 million fund for projects ai… [+8080 chars] This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.
# There is no doubt that NFTs or non-fungible tokens are the new cryptographic sensati… [+2996 chars] A representation of the virtual cryptocurrency Ethereum is seen among representations of other cryptocurrencies in this picture illustration taken June 14, 2021. REUTERS/Edgar Su/IllustrationJuly 26 … [+995 chars] By Reuters Staff
# FILE PHOTO: Representations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, Litecoin are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ru… [+1062 chars]

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
doc= nlp(eth_texts)
# Add a title to the document
# YOUR CODE HERE!
doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Blockchain infrastructure startups are heating up as industry fervor brings more developers and users to a space that still feels extremely young despite a heavy institutional embrace of the crypto s… [+2468 chars] While retail investors grew more comfortable buying cryptocurrencies like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin and Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the decentralized application world still has a lot of work to do when it comes to onboarding a… [+2288 chars] Representations of cryptocurrencies Bitcoin and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  are placed on PC motherboard in this illustration taken,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 29, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     REUTERS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dado Ruvic/IllustrationAug 3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - The
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  platform… [+2412 chars] Ether holders have &quot;staked&quot;
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than $13 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of the cryptocurrency on the ethereum
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Photothek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Ether holders have &quot;staked&quot;
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than $13 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of the cryptocurrency on the ethereum
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  network, as excitement … [+1935 chars] Representations of cryptocurrency
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  are placed on PC motherboard in this illustration taken,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 29, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     REUTERS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dado Ruvic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# /IllustrationNEW YORK,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Ethereum, the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Livepeer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has raised
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $20 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  for its decentralized video transcoding network built on the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethere

# %%
# List all Entities
# YOUR CODE HERE!
for ent in doc.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# Bitcoin and Ethereum ORG
# 2021 DATE
# Ethereum PERSON
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/IllustrationAug 3 PERSON
# Reuters ORG
# Ethereum PERSON
# more than $13 billion MONEY
# 2.0 CARDINAL
# Photothek PERSON
# more than $13 billion MONEY
# 2.0 CARDINAL
# Ethereum PERSON
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic PERSON
# July 30 DATE
# Reuters ORG
# second ORDINAL
# Livepeer PERSON
# $20 million MONEY
# Ethereum PERSON
# London GPE
# Ethereum PERSON
# 12 965 000 CARDINAL
# August 3-5, 2021 DATE
# Clie PERSON
# Spanish NORP
# AI ORG
# The Securities and Exchange Commission ORG
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration/File ORG
# NEW YORK GPE
# Reuters ORG
# the second half of the year DATE
# summer DATE
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration/File Photo ORG
# February 9, 2021 DATE
# REUTERS ORG
# Dado GPE
# Reuters ORG
# Tesla Inc ORG
# Reuters ORG
# Ethereum PERSON
# June 14, 2021 DATE
# REUTERS ORG
# Edgar Su/Il PERSON
# June 14, 2021 DATE
# REUTERS ORG
# Edgar Su/Illustration/FilesNEW YORK PERSON
# Aug 2 DATE
# Reuters ORG
# Chung Sung-Jun/Getty Images PERSON
# OpenSea ORG
# $1.5 billion MONEY
# Polygon ORG
# $100 million MONEY
# Spanish NORP
# AI ORG
# Ethereum PERSON
# June 14, 2021 DATE
# REUTERS ORG
# Edgar Su/ PERSON
# Reuters ORG
# FILE ORG
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ru PERSON

# %% [markdown]
# ---
